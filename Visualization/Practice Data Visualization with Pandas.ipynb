# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
#ts.head()
# Out:
#                value
# 2019-06-07  0.921758
# 2019-06-08 -0.216807
# 2019-06-09  1.420756
# 2019-06-10  1.106174
# 2019-06-11  0.466586

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  0.921758
# 2019-06-08  0.704951
# 2019-06-09  2.125707
# 2019-06-10  3.231881
# 2019-06-11  3.698467

# %%
ts.head()
# Out:
# 2019-06-07    0.370138
# 2019-06-08    1.604725
# 2019-06-09   -1.124133
# 2019-06-10    0.573836
# 2019-06-11    1.280447
# Freq: D, dtype: float64

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.370138
# 2019-06-08    1.974863
# 2019-06-09    0.850730
# 2019-06-10    1.424566
# 2019-06-11    2.705013
# Freq: D, dtype: float64

# %%
ts.plot(title='Series Plot', figsize=(15,6))

# %%
plt.plot(ts)

# %%
df.plot(title='Series Plot', figsize=(15,6))

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind='bar')

# %%
df = iris.drop(['species'], axis = 1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
plt.plot(df.iloc[0])

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='bar')

# %%
titanic['age'].plot.bar()

# %%
df = pd.DataFrame(randn(10,4), columns = ['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.550194  0.534306 -1.119046  1.428707
# 1  2.584532  1.924827 -0.302908  0.511357
# 2  0.520700 -0.481037  1.488085  0.602723
# 3 -0.133809  1.403341 -0.480553 -0.869646
# 4  2.836063 -0.203690  0.246076 -0.959734

# %%
df.plot(kind='bar')

# %%
df.plot.bar()

# %%
df.plot.barh()

# %%
iris.plot.hist(bins=15)

# %%
iris.plot(kind='hist',bins=15)

# %%
iris.plot(kind='hist', stacked=False, bins = 50)

# %%
iris['sepal_length'].plot(kind='hist', bins=50)

# %%
iris.plot(kind='hist',stacked=True, bins=50, orientation='horizontal', figsize = (15,8))

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist', stacked=True, bins=50, )

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color='r',alpha=0.9, figsize=(10,10)) # alpha denotes intesity of color
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026A404CAE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A404FC948>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026A40694148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A406CAAC8>]],
#       dtype=object)

# %%
df.diff().plot.hist(color='r',alpha=0.9, figsize=(10,10))

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length' ,c='sepal_width')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 75)

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 50)# s = size for size of dots

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,10))

# %%
d.plot(kind='pie')

# %%
d=df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True, figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000026A42B63408>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A42CC0BC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A42B63DC8>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 15, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000026A435DEC88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A437C4588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A435E6548>],
#       dtype=object)

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(8,8),diagonal='kde',color='r')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.plot(legend = True, figsize = (10, 5))

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000026A46584888>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A465A7948>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A46569B88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000026A4660BF08>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
df.plot(subplots = True, sharex = True, layout = (4,1), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-125-af09896ed1db> in <module>
# ----> 1 from descartes import PolygonPatch
#
# ModuleNotFoundError: No module named 'descartes'

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-335b3608a8ad> in <module>
# ----> 1 map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
#       2 # check data type so we can see that this is not a normal dataframe, but a GEOdataframe
#       3 map_df.head()
#       4 map_df.plot()
#
# NameError: name 'gpd' is not defined

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-127-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'
